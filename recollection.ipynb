# %%
import pandas as pd

# %%
# Load a sample
df = pd.read_csv("uncleaned_data_csv/standard.csv", nrows=20)
df.head()
# Out:
#    Unnamed: 0           Unnamed: 1 Unnamed: 2 Unnamed: 3      Unnamed: 4  \
# 0           1  Patrick van Aanholt     nl NED         DF  Crystal Palace
# 1           2       Rolando Aarons    eng ENG      MF,FW   Newcastle Utd
# 2           3       Rolando Aarons    eng ENG      MF,FW   Hellas Verona
# 3           4        Ignazio Abate     it ITA         DF           Milan
# 4           5      Aymen Abdennour     tn TUN         DF       Marseille
#
#            Unnamed: 5  Unnamed: 6    Rk  Player  Nation  ...  \
# 0  eng Premier League          26  1990      28      25  ...
# 1  eng Premier League          21  1995       4       1  ...
# 2          it Serie A          21  1995      11       6  ...
# 3          it Serie A          30  1986      17      11  ...
# 4          fr Ligue 1          27  1989       8       6  ...
#
#   npxG: Non-Penalty xG  xAG: Exp. Assisted Goals  npxG + xAG  \
# 0                 0.04                      0.25        0.21
# ...

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Rk', 'Player', 'Nation', 'Position',
#        'Squad', 'Competition', 'Age', 'Year of birth', 'Matches Played',
#        'Starts', 'Minutes', '90s Played', 'Goals', 'Assists',
#        'Goals + Assists', 'Non-Penalty Goals', 'Penalty Kicks Made',
#        'Penalty Kicks Attempted', 'Yellow Cards', 'Red Cards',
#        'xG: Expected Goals', 'npxG: Non-Penalty xG',
#        'xAG: Exp. Assisted Goals', 'npxG + xAG', 'Progressive Carries',
#        'Progressive Passes', 'Progressive Passes Rec', 'Goals/90',
#        'Assists/90', 'Goals + Assists/90', 'Non-Penalty Goals/90'],
#       dtype='object')
